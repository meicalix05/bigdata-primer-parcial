# %%
#EJERCICIO 1 Clasificacion de edad
def clasificar_edad(edad):
    if edad < 13:
        return "Niño"
    elif edad <= 17:
        return "Adolescente"
    elif edad <= 59:
        return "Adulto"
    else:
        return "Adulto mayor"

edad = 21
categoria = clasificar_edad(edad)
print(f"Edad: {edad} años")
print(f"Categoría: {categoria}")
# Out:
# Edad: 21 años
# Categoría: Adulto

# %%
#EJERCICIO 2 Conversor de temperatura
def convertir_a_fahrenheit(celsius):
    fahrenheit = (celsius * 9/5) + 32
    return fahrenheit

celsius = 25
fahrenheit = convertir_a_fahrenheit(celsius)
print(f"Temperatura en Celsius: {celsius}°C")
print(f"Temperatura en Fahrenheit: {fahrenheit}°F")
# Out:
# Temperatura en Celsius: 25°C
# Temperatura en Fahrenheit: 77.0°F

# %%
#EJERCICIO 3 Calculadora basica
def calculadora(num1, num2, operacion):
    if operacion == "suma":
        return num1 + num2
    elif operacion == "resta":
        return num1 - num2
    elif operacion == "multiplicacion":
        return num1 * num2
    elif operacion == "division":
        if num2 != 0:
            return num1 / num2
        else:
            return "Error: No se puede dividir entre cero"
    else:
        return "Error: Operación no válida"

num1 = 10
num2 = 5
operacion = "division"

resultado = calculadora(num1, num2, operacion)
print(f"Números: {num1} y {num2}")
print(f"Operación: {operacion}")
print(f"Resultado: {resultado}")
# Out:
# Números: 10 y 5
# Operación: division
# Resultado: 2.0

# %%
#EJERCICIO 10 Diccionario de estudiante
estudiante = {
    "nombre": "Esly Díaz",
    "edad": 24,
    "carrera": "Ingeniería en Sistemas",
    "promedio": 88.5,
    "estado": "Activo"
}
print("=== Datos del Estudiante ===")
for campo, valor in estudiante.items():
    print(f"  {campo.capitalize()}: {valor}")
# Out:
# === Datos del Estudiante ===
#   Nombre: Esly Díaz
#   Edad: 24
#   Carrera: Ingeniería en Sistemas
#   Promedio: 88.5
#   Estado: Activo

# %%
#EJERCICIO 4 Numero par o impar
def verificar_par_impar(numero):
    if numero % 2 == 0:
        return "Par"
    else:
        return "Impar"

numero = 8
resultado = verificar_par_impar(numero)

print(f"Número: {numero}")
print(f"Resultado: {resultado}")
# Out:
# Número: 8
# Resultado: Par

# %%
#EJERCICIO 5 Tabla de multiplicar
def tabla_multiplicar(numero):
    for i in range(1, 13):
        print(f"{numero} x {i} = {numero * i}")

numero = 7

print(f"Tabla de multiplicar del {numero}:")
tabla_multiplicar(numero)
# Out:
# Tabla de multiplicar del 7:
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70
# 7 x 11 = 77
# 7 x 12 = 84

# %%
#EJERCICIO 6 Contador de vocales
def contar_vocales(frase):
    vocales = "aeiou"
    contador = 0

    for letra in frase.lower():
        if letra in vocales:
            contador += 1

    return contador

frase = "La programacion en Python es muy util"
cantidad_vocales = contar_vocales(frase)

print(f"Frase: {frase}")
print(f"Cantidad de vocales: {cantidad_vocales}")
# Out:
# Frase: La programacion en Python es muy util
# Cantidad de vocales: 12

# %%
# Ejercicio 15: Limpieza básica de texto

frase = "   Hola   jasiel,   este   es   un   ejercicio   de   Python   "

print("Frase original:")
print(frase)

frase_limpia = frase.strip()

frase_limpia = frase_limpia.lower()

while "  " in frase_limpia:
    frase_limpia = frase_limpia.replace("  ", " ")

palabras = frase_limpia.split()

cantidad_palabras = len(palabras)

print("\nFrase limpia:")
print(frase_limpia)

print("\nCantidad de palabras:")
print(cantidad_palabras)

print("\nExplicación de métodos:")
print("strip(): elimina espacios al inicio y al final.")
print("lower(): convierte el texto a minúsculas.")
print("replace(): reemplaza texto.")
print("split(): separa el texto en palabras.")
# Out:
# Frase original:
#    Hola   jasiel,   este   es   un   ejercicio   de   Python
#
# Frase limpia:
# hola jasiel, este es un ejercicio de python
#
# Cantidad de palabras:
# 8
#
# Explicación de métodos:
# strip(): elimina espacios al inicio y al final.
# lower(): convierte el texto a minúsculas.
# replace(): reemplaza texto.
# split(): separa el texto en palabras.

# %%
#Ejercicio 7: Promedio de calificaciones

calificaciones = [85, 62, 90, 45, 78]
suma_total = sum(calificaciones)
cantidad_notas = len(calificaciones)
promedio = suma_total / cantidad_notas
print(f"Calificaciones: {calificaciones}")
print(f"Suma total: {suma_total}")
print(f"Promedio obtenido: {promedio:}")
if promedio >= 70:
    print("Estado del estudiante: APROBADO")
else:
    print("Estado del estudiante: REPROBADO")
# Out:
# Calificaciones: [85, 62, 90, 45, 78]
# Suma total: 360
# Promedio obtenido: 72.0
# Estado del estudiante: APROBADO

# %%
# Ejercicio 14: Registro de ventas

ventas = [
    {"cliente": "Carlos", "producto": "Laptop", "cantidad": 1, "precio_unitario": 15000},
    {"cliente": "María", "producto": "Mouse", "cantidad": 3, "precio_unitario": 250},
    {"cliente": "José", "producto": "Teclado", "cantidad": 2, "precio_unitario": 600}
]

total_general = 0
compra_mas_alta = 0
cliente_compra_mas_alta = ""

print("Registro de ventas:\n")

for venta in ventas:
    
    total_venta = venta["cantidad"] * venta["precio_unitario"]
    
    print("Cliente:", venta["cliente"])
    print("Producto:", venta["producto"])
    print("Cantidad:", venta["cantidad"])
    print("Precio unitario:", venta["precio_unitario"])
    print("Total venta:", total_venta)
    print("--------------------------")
    
    total_general += total_venta
    
    if total_venta > compra_mas_alta:
        compra_mas_alta = total_venta
        cliente_compra_mas_alta = venta["cliente"]

print("\nTotal general vendido:", total_general)
print("Cliente con la compra más alta:", cliente_compra_mas_alta)
print("Monto de compra más alta:", compra_mas_alta)
# Out:
# Registro de ventas:
#
# Cliente: Carlos
# Producto: Laptop
# Cantidad: 1
# Precio unitario: 15000
# Total venta: 15000
# --------------------------
# Cliente: María
# Producto: Mouse
# Cantidad: 3
# Precio unitario: 250
# Total venta: 750
# --------------------------
# Cliente: José
# Producto: Teclado
# Cantidad: 2
# Precio unitario: 600
# Total venta: 1200
# --------------------------
#
# Total general vendido: 16950
# Cliente con la compra más alta: Carlos
# Monto de compra más alta: 15000

# %%
#Ejercicio 8: Lista de números positivos y negativos

numeros = [12, -5, 0, 8, -23, 0, 45, -1, 7, -14]
positivos = 0
negativos = 0
ceros = 0

for num in numeros:
    if num > 0:
        positivos += 1
    elif num < 0:
        negativos += 1
    else:
        ceros += 1

print("RESUMEN FINAL")
print(f"Lista analizada: {numeros}")
print(f"Cantidad de numeros positivos: {positivos}")
print(f"Cantidad de numeros negativos: {negativos}")
print(f"Cantidad de ceros: {ceros}")
# Out:
# RESUMEN FINAL
# Lista analizada: [12, -5, 0, 8, -23, 0, 45, -1, 7, -14]
# Cantidad de numeros positivos: 4
# Cantidad de numeros negativos: 4
# Cantidad de ceros: 2

# %%
#Ejercicio 9: Mayor y menor de una lista

valores = [34, 89, 12, 56, 7, 92, 43, 21]
numero_mayor = max(valores)
numero_minor = min(valores)
diferencia = numero_mayor - numero_minor

print(f"Lista de numeros: {valores}")
print(f"Numero mayor: {numero_mayor}")
print(f"Numero menor: {numero_minor}")
print(f"Diferencia entre el mayor y el menor: {diferencia}")
# Out:
# Lista de numeros: [34, 89, 12, 56, 7, 92, 43, 21]
# Numero mayor: 92
# Numero menor: 7
# Diferencia entre el mayor y el menor: 85

# %%
# Ejercicio 13: Sistema simple de inventario

productos = [
    {"codigo": "P001", "nombre": "Laptop", "precio": 15000, "cantidad": 3},
    {"codigo": "P002", "nombre": "Mouse", "precio": 250, "cantidad": 10},
    {"codigo": "P003", "nombre": "Teclado", "precio": 600, "cantidad": 5}
]

print("Lista de productos:")

for producto in productos:
    print(producto)

codigo_buscar = "P002"
producto_encontrado = None

for producto in productos:
    if producto["codigo"] == codigo_buscar:
        producto_encontrado = producto

print("\nProducto encontrado:")
print(producto_encontrado)

valor_total = 0

for producto in productos:
    valor_total += producto["precio"] * producto["cantidad"]

print("\nValor total del inventario:", valor_total)
# Out:
# Lista de productos:
# {'codigo': 'P001', 'nombre': 'Laptop', 'precio': 15000, 'cantidad': 3}
# {'codigo': 'P002', 'nombre': 'Mouse', 'precio': 250, 'cantidad': 10}
# {'codigo': 'P003', 'nombre': 'Teclado', 'precio': 600, 'cantidad': 5}
#
# Producto encontrado:
# {'codigo': 'P002', 'nombre': 'Mouse', 'precio': 250, 'cantidad': 10}
#
# Valor total del inventario: 50500

# %%
#Ejercicio 11: Función para calcular descuento
def calcular_descuento(precio_original, porcentaje_descuento):
    monto_descuento = precio_original * (porcentaje_descuento / 100)
    precio_final = precio_original - monto_descuento
    return precio_final

precio = 1500.00
descuento = 20

precio_con_descuento = calcular_descuento(precio, descuento)
print(f"Precio original:    L. {precio:.2f}")
print(f"Descuento aplicado: {descuento}%")
print(f"Precio final:       L. {precio_con_descuento:.2f}")
# Out:
# Precio original:    L. 1500.00
# Descuento aplicado: 20%
# Precio final:       L. 1200.00
